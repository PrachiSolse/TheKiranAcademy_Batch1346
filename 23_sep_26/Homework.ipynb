# %%
name = "Prachi Solse"

print(name[0:6])
print(name[7:12])
print(name[:6])
print(name[7:])
print(name[:])
print(name[0:12:1])
print(name[0:12:2])
print(name[0:12:3])
print(name[1:6])
print(name[2:6])
print(name[0:5])
print(name[:7])
print(name[7:10])
print(name[-5:])
print(name[-5:-2])
print(name[:-5])
print(name[::2])
print(name[::3])
print(name[::-1])
print(name[11:6:-1])
# Out:
# Prachi
# Solse
# Prachi
# Solse
# Prachi Solse
# Prachi Solse
# Pah os
# Pc l
# rachi
# achi
# Prach
# Prachi
# Sol
# Solse
# Sol
# Prachi
# Pah os
# Pc l
# esloS ihcarP
# esloS
