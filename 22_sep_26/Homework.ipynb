# %%
# 1st Type
name="Prachi"
print(name[0])
# Out:
# P

# %%
# 2nd Type
name="Prachi"
print(name[-1])
# Out:
# i

# %%
# 3rd Type
name="Prachi"
print(name[5])
# Out:
# i

# %%
# 4th Type
name="Prachi"
print(name[0:4])
# Out:
# Prac

# %%
# 5th Type
name="Prachi"
print(name[-3:])
# Out:
# chi

# %%
# 6th Type
name="Prachi"
print(name[5:])
# Out:
# i

# %%
# 7th Type
name="Prachi"
print(name[:4])
# Out:
# Prac

# %%
# 8th Type
name="Prachi"
print(name[3::-1])
# Out:
# carP

# %%
# 9th Type
name="Prachi"
print(name[::2])
# Out:
# Pah

# %%
# 10th Type
name="Prachi"
print(name[-3:])
# Out:
# chi
